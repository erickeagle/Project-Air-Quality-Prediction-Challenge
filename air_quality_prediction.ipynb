# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('\Train.csv')

# %%
df
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5      target
# 0      0.293416  -0.945599  -0.421105   0.406816   0.525662  -82.154667
# 1     -0.836084  -0.189228  -0.776403  -1.053831   0.597997  -48.897960
# 2      0.236425   0.132836  -0.147723   0.699854  -0.187364   77.270371
# 3      0.175312   0.143194  -0.581111  -0.122107  -1.292168   -2.988581
# 4     -1.693011   0.542712  -2.798729  -0.686723   1.244077  -37.596722
# ...         ...        ...        ...        ...        ...         ...
# 1595  -0.274961  -0.820634  -0.757173  -0.147555  -0.307149  -80.110012
# 1596  -0.076099   0.255257   0.290054   1.796036   0.340350  118.315601
# 1597   1.044177  -0.899206   1.730399  -1.871057   0.442520 -107.510508
# 1598  -1.269173  -0.005052   1.857669  -1.080365   0.736334  -47.341558
# 1599  -1.884000  -0.849427  -1.452270   0.488613   1.459576 -115.939003
#
# [1600 rows x 6 columns]

# %%
df.shape
# Out:
# (1600, 6)

# %%
X=df[['feature_1','feature_2','feature_3','feature_4','feature_5']]
y=df['target']

# %%
X
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5
# 0      0.293416  -0.945599  -0.421105   0.406816   0.525662
# 1     -0.836084  -0.189228  -0.776403  -1.053831   0.597997
# 2      0.236425   0.132836  -0.147723   0.699854  -0.187364
# 3      0.175312   0.143194  -0.581111  -0.122107  -1.292168
# 4     -1.693011   0.542712  -2.798729  -0.686723   1.244077
# ...         ...        ...        ...        ...        ...
# 1595  -0.274961  -0.820634  -0.757173  -0.147555  -0.307149
# 1596  -0.076099   0.255257   0.290054   1.796036   0.340350
# 1597   1.044177  -0.899206   1.730399  -1.871057   0.442520
# 1598  -1.269173  -0.005052   1.857669  -1.080365   0.736334
# 1599  -1.884000  -0.849427  -1.452270   0.488613   1.459576
#
# [1600 rows x 5 columns]

# %%
y
# Out:
# 0       -82.154667
# 1       -48.897960
# 2        77.270371
# 3        -2.988581
# 4       -37.596722
#            ...
# 1595    -80.110012
# 1596    118.315601
# 1597   -107.510508
# 1598    -47.341558
# 1599   -115.939003
# Name: target, Length: 1600, dtype: float64

# %%
X.shape,y.shape
# Out:
# ((1600, 5), (1600,))

# %%
u=np.mean(X,axis=0)
std=np.std(X,axis=0)

print(u.shape,std.shape)
# Out:
# (5,) (5,)

# %%
X=(X-u)/std

# %%
X.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5
# 0   0.290165  -0.898712  -0.372381   0.441771   0.525024
# 1  -0.842705  -0.158229  -0.723656  -0.994642   0.598960
# 2   0.233004   0.157070  -0.102094   0.729947  -0.203782
# 3   0.171708   0.167210  -0.530576  -0.078377  -1.333037
# 4  -1.702188   0.558336  -2.723087  -0.633625   1.259339

# %%
ones  = np.ones((X.shape[0],1))
X=np.hstack((ones,X))
print(X.shape)
# Out:
# (1600, 6)

# %%
def hypothesis(X,theta):
  
    return np.dot(X,theta)

def error(X,y,theta):
    e=0.0
    m=X.shape[0]
    y_=hypothesis(X,theta)
    error=np.sum((y-y_)**2)
    return e/m

def gradient(X,y,theta):
    m =X.shape[0]
    y_=hypothesis(X,theta)
    grad=np.dot(X.T,(y_-y))
    
    return grad/m

def gradient_descent(X,y,learning_rate=0.1,max_epochs=300):
    n=X.shape[1]
    theta=np.zeros((n,))
    error_list=[]
    for i in range(max_epochs):
        e=error(X,y,theta)
        error_list.append(e)
        
        grad=gradient(X,y,theta)
        theta=theta-learning_rate*grad
    return theta,error_list

# %%
import time
start = time.time()
theta,error_list=gradient_descent(X,y)
end=time.time()
print("taken time",end-start)
# Out:
# taken time 0.31600141525268555

# %%
y_=hypothesis(X,theta)

# %%
y_
# Out:
# array([ -57.87196311,  -89.46019557,   53.95305942, ..., -115.65802541,
#         -64.27649688, -116.11442895])

# %%
def r2_score(Y,Y_):
    
    num=np.sum((Y-Y_)**2)
    denom=np.sum((Y-Y.mean())**2)
    score=(1-num/denom)
    return score*100

# %%
r2_score(y,y_)
# Out:
# 96.60939669975616

# %%
x_test=pd.read_csv('K:\Coding Blocks\Machine learning\Test.csv').values

ones  = np.ones((x_test.shape[0],1))
x_test=np.hstack((ones,x_test))
print(X.shape)


y_test=hypothesis(x_test,theta)
y_test.shape
# Out:
# (1600, 6)
# (400,)

# %%
y_test
# Out:
# array([ 112.15168366,  115.87976761,  -25.87626158,  -47.63583973,
#        -102.51798162,  -50.2893194 ,  -81.3683598 ,   20.93713793,
#         172.90067195,  170.88408456, -111.39443612,  -25.59613481,
#          -8.87208051,  120.36150946,   35.09400747,   41.78966378,
#        -199.41769455,   17.73984091,    8.5360946 ,  133.07321033,
#          61.45777124,  -68.39998714, -114.50737628,  -12.54690841,
#         -64.1804854 ,    7.52041889,   23.7846786 ,  104.7686305 ,
#          19.45718991,  -31.19280855,  107.80088039,  -51.11361967,
#         215.83283486,  -20.0027722 , -238.03992037,  152.5478055 ,
#          -8.26495851,    9.13276736, -318.7446708 ,   73.47903221,
#         -88.08890616, -214.92225985, -248.10351287,  132.65718304,
#         -80.84249   ,  101.17564239,   -9.18199391,   14.91509474,
#        -104.82054763,  -33.08742048,    7.17980668, -184.25133971,
#          60.85422477, -105.23084917, -112.70614897, -163.49566851,
# ...

# %%
df=pd.DataFrame(data=y_test,columns=["target"])

df.insert(0, "Id",'1')
df['Id'] = np.arange(len(df))
df

df.to_csv('y_air_pre.csv',index=False)
